# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import simulations_lpf

# %%
n_samples = 10
x_train_n,y_train,x_test_n,y_test,thresholds_train,thresholds_test,gt_importance_train,gt_importance_test = simulations_lpf.main(n_samples=n_samples, plot=True)
# Out:
# (8, 48)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
enc = OneHotEncoder(categories='auto',sparse=False)
enc.fit(np.reshape(np.array([0,1,2]),[-1,1]))
# Out:
# OneHotEncoder(categorical_features=None, categories='auto',
#        dtype=<class 'numpy.float64'>, handle_unknown='error',
#        n_values=None, sparse=False)

# %%
enc.transform(np.reshape(np.array([0,1,1]),[-1,1]))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 1., 0.]])

# %%
with open('data/simulated_data/x_test.pkl','rb') as f:
    x_test = pkl.load(f)

# %%
x_test.shape
# Out:
# (4000, 3, 50)

# %%
a = np.ones(5)

# %%
a[0:10]
# Out:
# array([1., 1., 1., 1., 1.])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import simulations_lpf

# %%
n_samples = 10
x_train_n,y_train,x_test_n,y_test,thresholds_train,thresholds_test = simulations_lpf.main(n_samples=n_samples, plot=True)
# Out:
# [0.01163101 0.06411287 0.01450343]

# %%
x_test_n.shape, x_train_n.shape
# Out:
# ((2, 3, 48), (8, 3, 48))

# %%
y_train.shape, y_test.shape
# Out:
# ((8, 48), (2, 48))

# %%
len(thresholds_train)
# Out:
# 8

# %%
import pickle as pkl

# %%
with open('data/simulated_data/x_test.pkl','rb') as f:
    x_test = pkl.load(f)

# %%
x_test.shape
# Out:
# (4000, 3, 50)

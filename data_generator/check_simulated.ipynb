# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import simulations_threshold_spikes as sims

# %%
np.logspace(0,np.log10(80),3)
# Out:
# array([ 1.        ,  8.94427191, 80.        ])

# %%
n_samples = 10
x_train_n,y_train,x_test_n,y_test,thresholds_train,thresholds_test, gt_importance_train, gt_importance_test= sims.main(n_samples=n_samples, plot=True)
# Out:
# 0
# samples done!
# (8, 80)

# %%
np.mean(x_train_n[:,0,:]), np.mean(x_train_n[:,1,:]), np.mean(x_train_n[:,2,:])
# Out:
# (0.3221464126989696, 0.6400273219833008, 0.28951358250754505)

# %%
np.min(x_train_n[:,0,:]), np.min(x_train_n[:,1,:]), np.min(x_train_n[:,2,:])
# Out:
# (-0.25716097787610975, 0.0015953207657700929, -0.1847248672360529)

# %%
np.max(x_train_n[:,0,:]), np.max(x_train_n[:,1,:]), np.max(x_train_n[:,2,:])
# Out:
# (1.4467013648641949, 2.05481258442933, 1.5793268837385288)

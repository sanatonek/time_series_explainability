# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
import pickle as pkl
import glob
from scipy.stats import entropy

# %%
kl={}
for p in np.linspace(0,1,6):
    kl[p] = []
    for x in np.linspace(0,1,20):
        kl[p].append(entropy([p,1-p],[x,1-x]))
        
    plt.plot(np.linspace(0,1,20),kl[p])
    plt.legend(str(p))

# %%
entropy([0.8,0.2],[0.6,0.4])
# Out:
# 0.09151622184943578

# %%
entropy([0.8,0.2],[1,0.0])
# Out:
# inf
